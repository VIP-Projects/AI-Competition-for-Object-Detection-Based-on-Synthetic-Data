# %%
import pandas as pd

df = pd.read_csv('./results/v2.csv')
df
# Out:
#                 file_name  class_id  confidence     point1_x    point1_y  \
# 0      test\064442001.png        25    0.895008  1135.899292  179.058823
# 1      test\064442001.png        26    0.496875  1139.686035  183.105362
# 2      test\064442001.png        16    0.456651  1136.673584  186.328552
# 3      test\064442001.png         7    0.077786  1138.567749  184.691956
# 4      test\064507368.png        20    0.988473   495.160858  128.271530
# ...                   ...       ...         ...          ...         ...
# 11243  test\183928410.png        28    0.050112   686.486206   55.178253
# 11244  test\184121675.png        28    0.987460   875.829102  554.403503
# 11245  test\184121675.png        27    0.653007   872.563049  568.181213
# 11246  test\184121675.png        21    0.300006   871.706421  565.806458
# 11247  test\184121675.png        22    0.156469   880.793091  550.630310
#
#           point2_x    point2_y     point3_x    point3_y     point4_x  \
# ...

# %%
df["file_name"]
# Out:
# 0       labels\064442001.png
# 1       labels\064507368.png
# 2       labels\065131036.png
# 3       labels\065147868.png
# 4       labels\065203472.png
#                 ...
# 5866    labels\183911746.png
# 5867    labels\183911746.png
# 5868    labels\183928410.png
# 5869    labels\183928410.png
# 5870    labels\184121675.png
# Name: file_name, Length: 5871, dtype: object

# %%
df["file_name"][0][7:]
# Out:
# '064442001.png'

# %%
for i in range(len(df["file_name"])):
    df["file_name"][i] = df["file_name"][i][7:]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12124\2183900404.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["file_name"][i] = df["file_name"][i][7:]
# C:\Users\user\AppData\Local\Temp\ipykernel_12124\2183900404.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["file_name"][i] = df["file_name"][i][7:]
# C:\Users\user\AppData\Local\Temp\ipykernel_12124\2183900404.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#           file_name  class_id  confidence  point1_x  point1_y  point2_x  \
# 0     064442001.png        16    0.541605      1139       180      1431
# 1     064507368.png        22    0.815908      1051         0      1241
# 2     065131036.png         4    0.944684      1110        54      1358
# 3     065147868.png        16    0.741026       727       188      1010
# 4     065203472.png         8    0.984570       541       760       830
# ...             ...       ...         ...       ...       ...       ...
# 5866  183911746.png        29    0.801600       888       593      1187
# 5867  183911746.png        22    0.735054       509       800       829
# 5868  183928410.png        27    0.984608       684        48       919
# 5869  183928410.png        22    0.881433       945         0      1192
# 5870  184121675.png        27    0.984897       879       557      1151
#
#       point2_y  point3_x  point3_y  point4_x  point4_y
# ...

# %%
df.to_csv('./results/yolov2_ep10_by4.csv')

# %%
# 실행끝나고 csv파일 열어서 1행 삭제해야함
